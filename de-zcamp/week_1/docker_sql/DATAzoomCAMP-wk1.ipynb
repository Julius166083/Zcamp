# %% [markdown]
# # YELLOW TAXI TRIP_DATA_2021_01

# %%
import pandas as pd

# %%
df = pd.read_csv('yellow_head100.csv')

# %%
df
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1          1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2          1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3          1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4          2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
# ..       ...                  ...                   ...              ...
# 94         2  2021-01-01 00:23:24   2021-01-01 00:34:29                2
# 95         2  2021-01-01 00:12:41   2021-01-01 00:26:47                1
# 96         2  2021-01-01 00:23:29   2021-01-01 00:35:03                2
# 97         2  2021-01-01 00:46:17   2021-01-01 00:54:25                2
# 98         2  2021-01-01 00:28:16   2021-01-01 00:51:44                1
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# ...

# %%
# convert df into a data definition language (DDL) that sql understands to describe how the shcema/table should look like
# in sql
pd.io.sql.get_schema(df, name= 'yellow_taxi_data_table')
# Out:
# 'CREATE TABLE "yellow_taxi_data_table" (\n"VendorID" INTEGER,\n  "tpep_pickup_datetime" TEXT,\n  "tpep_dropoff_datetime" TEXT,\n  "passenger_count" INTEGER,\n  "trip_distance" REAL,\n  "RatecodeID" INTEGER,\n  "store_and_fwd_flag" TEXT,\n  "PULocationID" INTEGER,\n  "DOLocationID" INTEGER,\n  "payment_type" INTEGER,\n  "fare_amount" REAL,\n  "extra" REAL,\n  "mta_tax" REAL,\n  "tip_amount" REAL,\n  "tolls_amount" REAL,\n  "improvement_surcharge" REAL,\n  "total_amount" REAL,\n  "congestion_surcharge" REAL\n)'

# %%
print(pd.io.sql.get_schema(df, name= 'yellow_taxi_data_table'))
# Out:
# CREATE TABLE "yellow_taxi_data_table" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TEXT,
#   "tpep_dropoff_datetime" TEXT,
#   "passenger_count" INTEGER,
#   "trip_distance" REAL,
#   "RatecodeID" INTEGER,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL
# )

# %%
# converting date stamps into pandas format and then passing result direct inot the table
df.tpep_pickup_datetime=pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime=pd.to_datetime(df.tpep_dropoff_datetime)

# %%
df
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1          1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2          1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3          1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4          2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
# ..       ...                  ...                   ...              ...
# 94         2  2021-01-01 00:23:24   2021-01-01 00:34:29                2
# 95         2  2021-01-01 00:12:41   2021-01-01 00:26:47                1
# 96         2  2021-01-01 00:23:29   2021-01-01 00:35:03                2
# 97         2  2021-01-01 00:46:17   2021-01-01 00:54:25                2
# 98         2  2021-01-01 00:28:16   2021-01-01 00:51:44                1
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# ...

# %%
# telling pandas to put row[0]/ the headings of the table into postgress, create a connection
# SQLAlchemy is the python library for dealig with SQL, needs to be installed
# its mostly installed alongside anaconda installaltions
# sqlalchemy didnt work i had to install "pip install psycopg2-binary"

from sqlalchemy import create_engine
import psycopg2

# %%
# !pip install psycopg2-binary

# %%
engine=create_engine('postgresql://root:root@localhost:5431/ny_taxi')

# %%
# this is the statement pandas will execute when creating this table in postgres
print(pd.io.sql.get_schema(df, name= 'yellow_taxi_data_table', con=engine))
# Out:
# CREATE TABLE yellow_taxi_data_table (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
# to chuck the whole "yellow_tripdata_2021-01" well shall use iterators break it down into batches 
# small chucks of 100,000 then for each chuck is put into the data base until whole scv file is complete

df_iter = pd.read_csv('yellow_tripdata_2021-01.csv', iterator=True, chunksize=100000)

# %%
# "next" in python returns the next element in the iterator
df=next(df_iter)

# %%
len(df)
# Out:
# 100000

# %%
# converting date stamps into pandas format and then passing result direct inot the table
df.tpep_pickup_datetime=pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime=pd.to_datetime(df.tpep_dropoff_datetime)

# %%
df.head(n=10)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
# 5         1  2021-01-01 00:16:29   2021-01-01 00:24:30                1
# 6         1  2021-01-01 00:00:28   2021-01-01 00:17:28                1
# 7         1  2021-01-01 00:12:29   2021-01-01 00:30:34                1
# 8         1  2021-01-01 00:39:16   2021-01-01 01:00:13                1
# 9         1  2021-01-01 00:26:12   2021-01-01 00:39:46                2
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10           1                  N           142            43
# ...

# %%
# creating a table with column headings then inserting data thereafter
# if-exists means if table name already exists replace with this one created
# lets do this on column names only and then go to CMD , do"\dt" to see the kind of table we have

df.head(n=0).to_sql(name='yellow_taxi_data_table', con=engine, if_exists='replace')

# %%
# now insert whole data into the table
# instead of replacing the created table, w'll append now
# %time df.to_sql(name='yellow_taxi_data_table', con=engine, if_exists='append')
# Out:
# Wall time: 13.6 s

# %%
from time import time

# %%
# iterative code to insert whole of the next dataset,
#when its done, it throws an error "stopiteration"
while True:
    t_start=time()
    
    df=next(df_iter)
    
    df.tpep_pickup_datetime=pd.to_datetime(df.tpep_pickup_datetime)
    df.tpep_dropoff_datetime=pd.to_datetime(df.tpep_dropoff_datetime)
    
    df.to_sql(name='yellow_taxi_data_table', con=engine, if_exists='append')
    
    t_end=time()
    print('inserted another chunck..., took %.3f seconds'%(t_end - t_start))
# Out:
# inserted another chunck..., took 13.822 seconds
# inserted another chunck..., took 14.832 seconds
# inserted another chunck..., took 13.455 seconds
# inserted another chunck..., took 14.312 seconds
# inserted another chunck..., took 15.908 seconds
# inserted another chunck..., took 16.746 seconds
# inserted another chunck..., took 14.206 seconds
# inserted another chunck..., took 18.559 seconds
# inserted another chunck..., took 18.476 seconds
# inserted another chunck..., took 16.465 seconds
# inserted another chunck..., took 16.714 seconds
# C:\Users\Dell\miniconda3\envs\firstEnv\lib\site-packages\IPython\core\interactiveshell.py:3377: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# inserted another chunck..., took 15.219 seconds
# inserted another chunck..., took 10.946 seconds
# ---------------------------------------------------------------------------
# ...

# %%
### PGAdmin best GUI tool to interact with postgres instead of using command prompt (pgcli)
## since we already have docker, we dont need to install it, just pbull its image in docker and use it
## google for PGAdmin docker follow instructions (docker pull dpage/pgadmin4)

# %% [markdown]
# # TAXI + ZONE LOOKUP DATA

# %%
df2 = pd.read_csv('taxi+_zone_lookup.csv')

# %%
df2.head(n=10)
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone
# 5           6  Staten Island  Arrochar/Fort Wadsworth    Boro Zone
# 6           7         Queens                  Astoria    Boro Zone
# 7           8         Queens             Astoria Park    Boro Zone
# 8           9         Queens               Auburndale    Boro Zone
# 9          10         Queens             Baisley Park    Boro Zone

# %%
pd.io.sql.get_schema(df2, name= 'taxi+_zone_lookup.csv')
print(pd.io.sql.get_schema(df2, name= 'taxi+_zone_lookup.csv'))
# Out:
# CREATE TABLE "taxi+_zone_lookup.csv" (
# "LocationID" INTEGER,
#   "Borough" TEXT,
#   "Zone" TEXT,
#   "service_zone" TEXT
# )

# %%
print(pd.io.sql.get_schema(df2, name= 'taxi_zone_lookup_table', con=engine))
# Out:
# CREATE TABLE taxi_zone_lookup_table (
# 	"LocationID" BIGINT,
# 	"Borough" TEXT,
# 	"Zone" TEXT,
# 	service_zone TEXT
# )

# %%
df2.head(n=0).to_sql(name='taxi_zone_lookup_table', con=engine, if_exists='replace')

# %%
# %time df2.to_sql(name='taxi_zone_lookup_table', con=engine, if_exists='append')
# Out:
# Wall time: 117 ms

# %%
len(df2)
# Out:
# 265

# %%
df3 = pd.read_csv('yellow_tripdata_2021-01.csv')

# %%
df3.tail(n=5)
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 1369760       NaN  2021-01-25 08:32:04   2021-01-25 08:49:32              NaN
# 1369761       NaN  2021-01-25 08:34:00   2021-01-25 09:04:00              NaN
# 1369762       NaN  2021-01-25 08:37:00   2021-01-25 08:53:00              NaN
# 1369763       NaN  2021-01-25 08:28:00   2021-01-25 08:50:00              NaN
# 1369764       NaN  2021-01-25 08:38:00   2021-01-25 08:50:00              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 1369760           8.80         NaN                NaN           135
# 1369761           5.86         NaN                NaN            42
# 1369762           4.45         NaN                NaN            14
# 1369763          10.04         NaN                NaN           175
# 1369764           4.93         NaN                NaN           248
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# ...

# %%
df2
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                       NV          NaN
# 264         265        Unknown                      NaN          NaN
#
# [265 rows x 4 columns]
